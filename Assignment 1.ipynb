# %% [markdown]
# ### Data Analytics Assignment
# #### Vishnu S Reddy
# #### PES2201800118
# #### B Section

# %% [markdown]
# ### 1. Read the BKB.csv dataset

# %%
data = read.csv("BKB.csv", header = TRUE)
data
# Out:
#      Applicant.ID Loan.Type        Gender Marital.Status Accomodation.Type
# 1     1           Home Loan        Male   Married        Family Other
# 2     2           Home Loan        Male   Married        Family Other
# 3     3           Home Loan        Male   Married        Company Provided
# 4     4           Home Improvement Male   Married        Owned
# 5     5           Home Loan        Male   Married        Family Other
# 6     6           Home Loan        Male   Married        Family Other
# 7     7           Home Loan        Male   Married        Family Other
# 8     8           Home Loan        Male   Married        Rented
# 9     9           Home Loan        Female Married        Family Other
# 10   10           Home Loan        Male   Married        Family Other
# 11   11           Home Loan        Male   Married        Family Other
# 12   12           Home Loan        Female Married        Rented
# 13   13           Home Loan        Male   Married        Rented
# ...

# %% [markdown]
# ### 2. Find a basic summary of the data

# %%
summary(data)
# Out:
#   Applicant.ID               Loan.Type       Gender     Marital.Status
#  Min.   :   1.0   Home Improvement: 352   Female: 340   Married:3483
#  1st Qu.: 966.8   Home Loan       :3512   Male  :3524   Others :  42
#  Median :1932.5                                         Single : 339
#  Mean   :1932.5
#  3rd Qu.:2898.2
#  Max.   :3864.0
#         Accomodation.Type No.of.years.in.the.current.address
#  Company Provided:  88    Min.   : 0.0
#  Family Other    : 976    1st Qu.: 2.0
#  Owned           :1029    Median : 6.0
#  Rented          :1771    Mean   :10.6
#                           3rd Qu.:15.0
#                           Max.   :92.0
#  No..of.Years.in.the.current.job Monthly.Salary   Balance.in.Savings.Account
#  Min.   : 0.00                   Min.   :     0   Min.   :      0
#  1st Qu.: 5.00                   1st Qu.: 12201   1st Qu.:   1500
#  Median :10.00                   Median : 19000   Median :   6358
#  Mean   :10.93                   Mean   : 22619   Mean   :  31583
# ...

# %% [markdown]
# ### 3. Are there any outliers in these variables? Plot a box and whisker plot to find out.

# %%
boxplot(data$No.of.years.in.the.current.address)
# Out:
# plot without title

# %%
boxplot(data$No..of.Years.in.the.current.job)
# Out:
# plot without title

# %%
boxplot(data$Monthly.Salary)
# Out:
# plot without title

# %%
boxplot(data$Balance.in.Savings.Account)
# Out:
# plot without title

# %%
boxplot(data$Loan.Amount.Requested)
# Out:
# plot without title

# %%
boxplot(data$Term)
# Out:
# plot without title

# %%
boxplot(data$Down.Payment)
# Out:
# plot without title

# %%
boxplot(data$EMI.Affordable)
# Out:
# plot without title

# %% [markdown]
# ###### As we can see from the above plots, it is very obvious that there are quite a few outliers.

# %% [markdown]
# ### 4. Visualize the Loan Amount attribute

# %%
loanAmount <- data$Loan.Amount

# %%
hist(loanAmount,
    main="Visualizing the Loan Amount",
    xlab="Loan Amount")
# Out:
# Plot with title “Visualizing the Loan Amount”

# %%
hist(loanAmount,
    main="Visualizing the Loan Amount",
    xlab="Loan Amount",
    breaks = 15 )
# Out:
# Plot with title “Visualizing the Loan Amount”
